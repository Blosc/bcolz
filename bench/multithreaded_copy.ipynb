# %% [markdown]
# # Measure copy times when using multi-threading

# %% [markdown]
# This notebook profiles a very simple copy operation on large arrays (~1 GB), using synthetic data (random walk).

# %%
import numpy as np
import bcolz
from bcolz.utils import human_readable_size

# %%
import multiprocessing
import dask
import dask.array as da
from dask.diagnostics import Profiler, ResourceProfiler, CacheProfiler
from dask.diagnostics.profile_visualize import visualize
import bokeh
from bokeh.io import output_notebook
output_notebook()
# Out:
#     <div class="bk-banner">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="63764ed7-ac0d-4454-8adc-9a012a333d2c">Loading BokehJS ...</span>
#     </div>

# %%
def profile_dask_copy(src, dst, chunks, num_workers=multiprocessing.cpu_count(), dt=0.1, lock=True):
    dsrc = da.from_array(src, chunks=chunks)
    with Profiler() as prof, ResourceProfiler(dt=dt) as rprof:
        da.store(dsrc, dst, num_workers=num_workers, lock=lock)
    visualize([prof, rprof])

# %% [markdown]
# ## NumPy arrays

# %%
a = np.cumsum(np.random.random_sample(150*1000*1000)-0.5)  # random walk
human_readable_size(a.nbytes)
# Out:
# '1.12 GB'

# %%
# %time a2 = a.copy()
# Out:
# CPU times: user 176 ms, sys: 280 ms, total: 456 ms
# Wall time: 458 ms

# %%
profile_dask_copy(a, a2, chunks=1000*1000, lock=False, dt=0.05)
# Out:
#     <div class="plotdiv" id="38332225-9eb9-41c9-aae7-bd0f19fc9c91"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("38332225-9eb9-41c9-aae7-bd0f19fc9c91");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '38332225-9eb9-41c9-aae7-bd0f19fc9c91' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"63fb46c1-6799-4a68-b717-4aaabdae88f5":{"roots":{"references":[{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fc25a56-d486-406d-989f-ad5420857d52","type":"Rect"},{"attributes":{"axis_label":null,"axis_line_color":{"value":null},"formatter":{"id":"4ac94cd8-fbf2-40a1-8bfe-edf36310bcaa","type":"BasicTickFormatter"},"major_tick_line_color":{"value":null},"plot":{"id":"48f69357-93e2-4583-9177-6ce9851b446a","subtype":"Figure","type":"Plot"},"ticker":{"id":"104b7b74-7cda-45b4-95bd-1c09c676526b","type":"BasicTicker"}},"id":"fcafd6a2-70ae-48e0-89c7-13bc4b9d4c12","type":"LinearAxis"},{"attributes":{"callback":null,"end":0.30487990379333496},"id":"6a6f8733-9437-4e73-9c17-b707f990d090","type":"Range1d"},{"attributes":{},"id":"e0226192-fd00-47f0-a1ed-6b02f693cee1","type":"CategoricalTickFormatter"},{"attributes":{"axis_label":"Time (s)","formatter":{"id":"58be163b-0412-43c4-9e65-295c279f3662","type":"BasicTickFormatter"},"plot":{"id":"a5a7b579-6a98-41bd-ae22-91dead25553c","subtype":"Figure","type":"Plot"},"ticker":{"id":"8c6b6675-f011-4f38-897b-9ccc75db2863","type":"BasicTicker"}},"id":"79a38d63-00d6-42bc-9641-4698cd27842e","type":"LinearAxis"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"x":{"field":"x"},"y":{"field":"y"}},"id":"cd64a9d2-eeb3-4b88-939a-5d00e74340d5","type":"Line"},{"attributes":{"plot":{"id":"48f69357-93e2-4583-9177-6ce9851b446a","subtype":"Figure","type":"Plot"}},"id":"154211cd-4c36-42f2-94c0-2e050d63be09","type":"PreviewSaveTool"},{"attributes":{"callback":null,"end":791.0},"id":"455f5e5a-850c-41f8-81dc-01e649d0d3ea","type":"Range1d"},{"attributes":{"below":[{"id":"fcafd6a2-70ae-48e0-89c7-13bc4b9d4c12","type":"LinearAxis"}],"left":[{"id":"0b7d3c12-4de1-48f2-b7a1-c86f8d4b086e","type":"CategoricalAxis"}],"min_border_bottom":20,"min_border_left":75,"min_border_right":75,"plot_height":270,"plot_width":800,"renderers":[{"id":"fcafd6a2-70ae-48e0-89c7-13bc4b9d4c12","type":"LinearAxis"},{"id":"d886d2e1-f22d-41a1-a5bc-691d8faeea55","type":"Grid"},{"id":"0b7d3c12-4de1-48f2-b7a1-c86f8d4b086e","type":"CategoricalAxis"},{"id":"4f9da7f7-6b46-4243-9612-6d43b2d34c60","type":"Grid"},{"id":"427062cd-ee70-4d79-8bbe-cbe8d709eb44","type":"GlyphRenderer"}],"title":"Profile Results","tool_events":{"id":"c4d3bdd1-0d25-40af-bebd-afabe39a9829","type":"ToolEvents"},"tools":[{"id":"48631a60-7810-4381-b89f-8e7ddf84ed19","type":"HoverTool"},{"id":"154211cd-4c36-42f2-94c0-2e050d63be09","type":"PreviewSaveTool"},{"id":"b2fe8630-0b70-4012-961a-1a4ba0fc5dde","type":"ResetTool"},{"id":"f551cc15-8732-4149-8f45-3ead7efaa52e","type":"ResizeTool"},{"id":"6b167e7d-7147-4433-beeb-78054fa0735e","type":"WheelZoomTool"},{"id":"82278107-6457-4d1a-ab36-92ec46e44aef","type":"PanTool"}],"x_range":{"id":"6a6f8733-9437-4e73-9c17-b707f990d090","type":"Range1d"},"y_range":{"id":"eca9bd85-f4a2-4cd3-9eea-07cb984a07d5","type":"FactorRange"}},"id":"48f69357-93e2-4583-9177-6ce9851b446a","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"d2df96e6-c1ee-4dca-9697-a4ad10bbb679","type":"CategoricalTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.051789045333862305,0.10213303565979004,0.15271306037902832,0.20330500602722168,0.25393199920654297,0.30448389053344727],"y":[4957.499392,4957.958144,4958.02368,4958.208,4958.212096,4958.212096,4958.236672]}},"id":"aa293878-5d8e-401b-937e-c90bff162baf","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"a5a7b579-6a98-41bd-ae22-91dead25553c","subtype":"Figure","type":"Plot"},"ticker":{"id":"8c6b6675-f011-4f38-897b-9ccc75db2863","type":"BasicTicker"}},"id":"5e2c54f1-4e6f-46f6-b54a-7d67a6f6e398","type":"Grid"},{"attributes":{"plot":{"id":"a5a7b579-6a98-41bd-ae22-91dead25553c","subtype":"Figure","type":"Plot"}},"id":"ab800700-0aa2-4d16-9fbc-eb283973779d","type":"ResizeT ...

# %% [markdown]
# ## Bcolz carrays (in-memory)

# %%
import bcolz
bcolz.cparams.setdefaults(cname='lz4', clevel=5, shuffle=bcolz.BITSHUFFLE)  # use LZ4 and bitshuffle

# %%
# Check with no compression first
ca1 = bcolz.carray(a, cparams=bcolz.cparams(clevel=0))
ca1
# Out:
# carray((150000000,), float64)
#   nbytes: 1.12 GB; cbytes: 1.12 GB; ratio: 1.00
#   cparams := cparams(clevel=0, shuffle=2, cname='lz4', quantize=0)
# [ -3.28066043e-01  -5.13630983e-01  -8.95430781e-01 ...,  -1.57147748e+03
#   -1.57151374e+03  -1.57150456e+03]

# %%
# %time ca2 = ca1.copy(cparams=bcolz.cparams(clevel=0))
print(human_readable_size(ca2.cbytes))
# Out:
# CPU times: user 780 ms, sys: 388 ms, total: 1.17 s
# Wall time: 586 ms
# 1.12 GB

# %% [markdown]
# When using no compression, we see the true cost of storing data in non-compressed state internally in bcolz.  In this case, the time is significantly larger than numpy, but also larger than using compression:

# %%
# Now, for the compressed case
ca = bcolz.carray(a, cparams=bcolz.cparams(quantize=3))   # keep 3 significant digits
ca
# Out:
# carray((150000000,), float64)
#   nbytes: 1.12 GB; cbytes: 246.81 MB; ratio: 4.64
#   cparams := cparams(clevel=5, shuffle=2, cname='lz4', quantize=3)
# [ -3.28125000e-01  -5.13671875e-01  -8.95507812e-01 ...,  -1.57147748e+03
#   -1.57151374e+03  -1.57150456e+03]

# %%
# %time ca2 = ca.copy(cparams=bcolz.cparams(clevel=5))
print(human_readable_size(ca2.cbytes))
# Out:
# CPU times: user 2.44 s, sys: 232 ms, total: 2.67 s
# Wall time: 509 ms
# 246.81 MB

# %% [markdown]
# The copy times when using compression are better than without using compression (this is not that unusual for compressible datasets) and pretty close to numpy.copy() (just between 1x and 4x slower, depending on the run and the machine).

# %% [markdown]
# ## bcolz + dask + compression

# %%
profile_dask_copy(ca, ca2, chunks=ca.chunklen, lock=True, dt=0.05)
# Out:
#     <div class="plotdiv" id="6b037358-1e2b-4f6f-935b-ad50af631b32"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6b037358-1e2b-4f6f-935b-ad50af631b32");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6b037358-1e2b-4f6f-935b-ad50af631b32' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f9f1ea29-c34a-4829-a0d0-3e12e54498c1":{"roots":{"references":[{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fc25a56-d486-406d-989f-ad5420857d52","type":"Rect"},{"attributes":{"callback":null,"column_names":["function","color","width","key","y","x"],"data":{"color":["#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2 ...

# %%
profile_dask_copy(ca, ca2, chunks=ca.chunklen, lock=False, dt=0.05)
# Out:
#     <div class="plotdiv" id="673968ef-c262-4679-ac92-d950a2455b2f"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("673968ef-c262-4679-ac92-d950a2455b2f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '673968ef-c262-4679-ac92-d950a2455b2f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a9797d02-6626-4e5b-bdc2-2ff77e91a265":{"roots":{"references":[{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fc25a56-d486-406d-989f-ad5420857d52","type":"Rect"},{"attributes":{"callback":null,"column_names":["function","color","width","key","y","x"],"data":{"color":["#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2 ...

# %% [markdown]
# In this case, bcolz + dask copying time is pretty close to bcolz.copy() which uses internal Blosc threads.

# %% [markdown]
# ## Zarr arrays (in-memory)

# %%
import zarr
print('zarr', zarr.__version__)
# Out:
# ('zarr', '1.0.0b6.dev18')

# %%
# Check with no compression first
za1 = zarr.array(ca, chunks=ca.chunklen, compression=None)
za1
# Out:
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: none; compression_opts: None
#   nbytes: 1.1G; nbytes_stored: 1.1G; ratio: 1.0; initialized: 573/573
#   store: __builtin__.dict

# %%
za2 = zarr.empty_like(za1)
za2
# Out:
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: none; compression_opts: None
#   nbytes: 1.1G; nbytes_stored: 230; ratio: 5217391.3; initialized: 0/573
#   store: __builtin__.dict

# %%
# %time za2[:] = za1
za2
# Out:
# CPU times: user 196 ms, sys: 244 ms, total: 440 ms
# Wall time: 437 ms
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: none; compression_opts: None
#   nbytes: 1.1G; nbytes_stored: 1.1G; ratio: 1.0; initialized: 573/573
#   store: __builtin__.dict

# %% [markdown]
# In the non-compressed case, zarr takes significantly less time than using compression (see below).  That probably means that zarr, contrarily to bcolz, does not store uncompressed data in Blosc containers, so avoiding the penalty of handling small data blocks (which is the case for bcolz, see above).

# %%
# Now, for the compressed case
za = zarr.array(ca, chunks=ca.chunklen, compression='blosc', 
                compression_opts=dict(cname='lz4', clevel=5, shuffle=2))
za
# Out:
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: blosc; compression_opts: {u'cname': u'lz4', u'shuffle': 2, u'clevel': 5}
#   nbytes: 1.1G; nbytes_stored: 245.4M; ratio: 4.7; initialized: 573/573
#   store: __builtin__.dict

# %%
za2 = zarr.empty_like(za)
za2
# Out:
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: blosc; compression_opts: {u'cname': u'lz4', u'shuffle': 2, u'clevel': 5}
#   nbytes: 1.1G; nbytes_stored: 302; ratio: 3973509.9; initialized: 0/573
#   store: __builtin__.dict

# %%
# %time za2[:] = za
za2
# Out:
# CPU times: user 1.8 s, sys: 96 ms, total: 1.9 s
# Wall time: 555 ms
# zarr.core.Array((150000000,), float64, chunks=(262144,), order=C)
#   compression: blosc; compression_opts: {u'cname': u'lz4', u'shuffle': 2, u'clevel': 5}
#   nbytes: 1.1G; nbytes_stored: 245.4M; ratio: 4.7; initialized: 573/573
#   store: __builtin__.dict

# %% [markdown]
# For the compressed case, zarr takes similar time (more or less, depending on the run) than bcolz when copying, which is the expected thing.

# %% [markdown]
# ## zarr + dask + compression

# %%
profile_dask_copy(za, za2, chunks=za.chunks, lock=True, dt=0.05)
# Out:
#     <div class="plotdiv" id="cbef20c5-0fe6-464d-894e-0d474c8d15e7"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("cbef20c5-0fe6-464d-894e-0d474c8d15e7");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'cbef20c5-0fe6-464d-894e-0d474c8d15e7' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"96f7c062-cd96-489f-b103-5aedf33a9e93":{"roots":{"references":[{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fc25a56-d486-406d-989f-ad5420857d52","type":"Rect"},{"attributes":{"callback":null,"column_names":["function","color","width","key","y","x"],"data":{"color":["#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2 ...

# %%
profile_dask_copy(za, za2, chunks=za.chunks, lock=False, dt=0.05)
# Out:
#     <div class="plotdiv" id="d689b788-174f-4326-be75-fb0eef28a55a"></div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d689b788-174f-4326-be75-fb0eef28a55a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd689b788-174f-4326-be75-fb0eef28a55a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"45cfd21b-f79a-42de-88ff-549f253cd8ca":{"roots":{"references":[{"attributes":{"fill_color":{"field":"color"},"height":{"units":"data","value":1},"line_color":{"value":"gray"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2fc25a56-d486-406d-989f-ad5420857d52","type":"Rect"},{"attributes":{"callback":null,"column_names":["function","color","width","key","y","x"],"data":{"color":["#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2c7fb8","#2 ...

# %% [markdown]
# Here it seems that dask + zarr actually do improve speed over zarr + Blosc internal threads, and the copying times are better than for dask + bcolz.  The latter might be due to the fact that bcolz is not optimized (yet) for `ca2[:] = ca` operations and `ca.copy()` is usually faster.
